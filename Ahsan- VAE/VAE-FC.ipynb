# %%
#imports
import argparse
import torch
import torch.utils.data
import pickle
import numpy as np
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import tables

# %%
# Training settings
cuda = torch.cuda.is_available()

seed = 10


kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}
imagesize ={'x':100,'y':100,'c':3}
n_classes = 10
X_dim = imagesize['x']*imagesize['y']*imagesize['c']
z_dim = 1000
y_dim = 10
train_batch_size = 20
valid_batch_size = 20
N = 5000
epochs = 500 #500

# %%
##################################
# Load data and create Data loaders
##################################
def load_data(data_path='../data/'):
    print('loading data!')
    filepath = "data/train_data"
    hdf5_file = tables.open_file(filepath, "r")
    # To access images array:
    trainset_unlabeled = hdf5_file.root.images
    #hdf5_file = tables.open_file(filepath, "r")
    #for i in range(len(trainset_unlabeled)):
    #    plt.imshow(trainset_unlabeled[i])
    #    plt.show()
    #print(len(trainset_unlabeled))
    #print(np.shape(trainset_unlabeled[0]))
    #trainset_unlabeled = pickle.load(open(data_path + "train_unlabeled.p", "rb"))
    # Set -1 as labels for unlabeled data
    trainset_unlabeled.train_labels = hdf5_file.root.labels
    filepath = "data/test_data"
    hdf5_file = tables.open_file(filepath, "r")
    # To access images array:
    validset_unlabeled = hdf5_file.root.images
    trainset_unlabeled.labels = hdf5_file.root.labels
    
    train_unlabeled_loader = torch.utils.data.DataLoader(trainset_unlabeled,
                                                         batch_size=train_batch_size,
                                                         shuffle=True, **kwargs)

    return train_unlabeled_loader,trainset_unlabeled

# %%
##################################
# Define Networks
##################################
# Encoder
class Q_net(nn.Module):
    def __init__(self):
        super(Q_net, self).__init__()
        self.lin1 = nn.Linear(X_dim, N)
        self.lin2 = nn.Linear(N, N)
        # Gaussian code (z)
        self.lin3gauss = nn.Linear(N, z_dim)

    def forward(self, x):
        x = F.dropout(self.lin1(x), p=0.2, training=self.training)
        x = F.relu(x)
        x = F.dropout(self.lin2(x), p=0.2, training=self.training)
        x = F.relu(x)
        xgauss = self.lin3gauss(x)

        return xgauss

# %%
# Decoder
class P_net(nn.Module):
    def __init__(self):
        super(P_net, self).__init__()
        self.lin1 = nn.Linear(z_dim, N)
        self.lin2 = nn.Linear(N, N)
        self.lin3 = nn.Linear(N, X_dim)

    def forward(self, x):
        x = self.lin1(x)
        x = F.dropout(x, p=0.2, training=self.training)
        x = F.relu(x)
        x = self.lin2(x)
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.lin3(x)
        return F.sigmoid(x)

# %%
class D_net_gauss(nn.Module):
    def __init__(self):
        super(D_net_gauss, self).__init__()
        self.lin1 = nn.Linear(z_dim, N)
        self.lin2 = nn.Linear(N, N)
        self.lin3 = nn.Linear(N, 1)

    def forward(self, x):
        x = F.dropout(self.lin1(x), p=0.2, training=self.training)
        x = F.relu(x)
        x = F.dropout(self.lin2(x), p=0.2, training=self.training)
        x = F.relu(x)

        return F.sigmoid(self.lin3(x))

# %%
####################
# Utility functions
####################
def save_model(model, filename):
    print('Best model so far, saving it...')
    torch.save(model.state_dict(), filename)


def report_loss(epoch, D_loss_gauss, G_loss, recon_loss,valid_recon_loss):
    '''
    Print loss
    '''
    print('Epoch-{}; D_loss_gauss: {:.4}; G_loss: {:.4}; recon_loss: {:.4}; valid_recon_loss: {:.4}'.format(epoch,
                                                                                   D_loss_gauss.data[0],
                                                                                   G_loss.data[0],
                                                                                   recon_loss.data[0],valid_recon_loss.data[0]))


def create_latent(Q, loader):
    '''
    Creates the latent representation for the samples in loader
    return:
        z_values: numpy array with the latent representations
        labels: the labels corresponding to the latent representations
    '''
    Q.eval()
    labels = []

    for batch_idx, (X, target) in enumerate(loader):

        X = X * 0.3081 + 0.1307
        # X.resize_(loader.batch_size, X_dim)
        X, target = Variable(X), Variable(target)
        labels.extend(target.data.tolist())
        if cuda:
            X, target = X.cuda(), target.cuda()
        # Reconstruction phase
        z_sample = Q(X)
        if batch_idx > 0:
            z_values = np.concatenate((z_values, np.array(z_sample.data.tolist())))
        else:
            z_values = np.array(z_sample.data.tolist())
    labels = np.array(labels)

    return z_values, labels

# %%
       
####################
# Train procedure
####################
def train(P, Q, D_gauss, P_decoder, Q_encoder, Q_generator, D_gauss_solver, data_loader,valid_data,update_disc = True):
    '''
    Train procedure for one epoch.
    '''
    TINY = 1e-15
    # Set the networks in train mode (apply dropout when needed)
    Q.train()
    P.train()
    D_gauss.train()

    # Loop through the labeled and unlabeled dataset getting one batch of samples from each
    # The batch size has to be a divisor of the size of the dataset or it will return
    # invalid samples
    last_g_loss = 100
    last_g_grad = 1
    v_size = len(valid_data)
    v_data = np.zeros((v_size,imagesize['x'],imagesize['y'],imagesize['c']))
    for i in range(v_size):
        v_data[i] = np.array(valid_data[i])
    v_data = 1 - v_data/255
    V = Variable(torch.FloatTensor(v_data).resize_(valid_batch_size, X_dim))
    if cuda:
            V= V.cuda()
    for X in data_loader:
        # Load batch and normalize samples to be between 0 and 1
        X = 1-X/255
        X.resize_(train_batch_size, X_dim)
        X= Variable(X)
        X = X.type(torch.FloatTensor)
        if cuda:
            X= X.cuda()

        # Init gradients
        P.zero_grad()
        Q.zero_grad()
        D_gauss.zero_grad()

        #######################
        # Reconstruction phase
        #######################
        z_sample = Q(X)
        X_sample = P(z_sample)
        recon_loss = F.binary_cross_entropy(X_sample + TINY, X.resize(train_batch_size, X_dim) + TINY)
        recon_loss.backward()
        P_decoder.step()
        Q_encoder.step()

        P.zero_grad()
        Q.zero_grad()
        
        # recon loss for valid set
        z_sample = Q(V)
        X_sample = P(z_sample)
        recon_loss_valid = F.binary_cross_entropy(X_sample + TINY, X.resize(train_batch_size, X_dim) + TINY)
        P.zero_grad()
        Q.zero_grad()
        
        D_gauss.zero_grad()

        #######################
        # Regularization phase
        #######################
        # Discriminator
        Q.eval()
        z_real_gauss = Variable(torch.randn(train_batch_size, z_dim) * 5.)
        if cuda:
            z_real_gauss = z_real_gauss.cuda()

        z_fake_gauss = Q(X)

        D_real_gauss = D_gauss(z_real_gauss)
        D_fake_gauss = D_gauss(z_fake_gauss)
        D_loss = -torch.mean(torch.log(D_real_gauss + TINY) + torch.log(1 - D_fake_gauss + TINY))
        if last_g_loss < D_loss.data[0]: #update_disc:
            #print(last_g_grad,D_loss.data[0])
            #print('updating descriminator')
            D_loss.backward()
            D_gauss_solver.step()

        P.zero_grad()
        Q.zero_grad()
        D_gauss.zero_grad()

        # Generator
        Q.train()
        z_fake_gauss = Q(X)

        D_fake_gauss = D_gauss(z_fake_gauss)
        G_loss = -torch.mean(torch.log(D_fake_gauss + TINY))
        last_g_grad = last_g_loss - G_loss.data[0]
        last_g_loss = G_loss.data[0]
        G_loss.backward()
        Q_generator.step()

        P.zero_grad()
        Q.zero_grad()
        D_gauss.zero_grad()
    return D_loss, G_loss, recon_loss, recon_loss_valid

# %%
def generate_model( train_unlabeled_loader,valid_data):
    torch.manual_seed(10)

    if cuda:
        Q = Q_net().cuda()
        P = P_net().cuda()
        D_gauss = D_net_gauss().cuda()
    else:
        Q = Q_net()
        P = P_net()
        D_gauss = D_net_gauss()

    # Set learning rates
    gen_lr = 0.001
    reg_lr = 0.00005

    # Set optimizators
    P_decoder = optim.Adam(P.parameters(), lr=gen_lr)
    Q_encoder = optim.Adam(Q.parameters(), lr=gen_lr)

    Q_generator = optim.Adam(Q.parameters(), lr=reg_lr)
    D_gauss_solver = optim.Adam(D_gauss.parameters(), lr=reg_lr)
    losses = []
    update_disc = True
    for epoch in range(epochs):
        D_loss_gauss, G_loss, recon_loss,recon_loss_valid = train(P, Q, D_gauss, P_decoder, Q_encoder,
                                                 Q_generator,
                                                 D_gauss_solver,
                                                 train_unlabeled_loader,valid_data,update_disc)
        if epoch % 1 == 0:#chaged here!
            report_loss(epoch, D_loss_gauss, G_loss, recon_loss,recon_loss_valid)
            losses.append((epoch, D_loss_gauss.data[0], G_loss.data[0], recon_loss.data[0],recon_loss_valid.data[0]))
            #update_disc = D_loss_gauss.data[0] > G_loss.data[0]
    return Q, P

# %%
if __name__ == '__main__':
    train_unlabeled_loader,valid_data = load_data()
    Q, P = generate_model( train_unlabeled_loader,valid_data)
# Out:
# loading data!
# Epoch-0; D_loss_gauss: 1.002; G_loss: 1.312; recon_loss: 0.6932; valid_recon_loss: 0.7187
# Epoch-1; D_loss_gauss: 1.415; G_loss: 0.6324; recon_loss: 1.118; valid_recon_loss: 0.5964
# Epoch-2; D_loss_gauss: 1.889; G_loss: 0.294; recon_loss: 0.5297; valid_recon_loss: 1.856
# Epoch-3; D_loss_gauss: 1.511; G_loss: 0.5904; recon_loss: 4.769; valid_recon_loss: 0.6804
# Epoch-4; D_loss_gauss: 1.283; G_loss: 0.6616; recon_loss: 1.245; valid_recon_loss: 0.6114
# Epoch-5; D_loss_gauss: 1.352; G_loss: 0.6796; recon_loss: 0.5293; valid_recon_loss: 0.5834
# Epoch-6; D_loss_gauss: 1.402; G_loss: 0.6654; recon_loss: 0.6137; valid_recon_loss: 0.5796
# Epoch-7; D_loss_gauss: 1.338; G_loss: 0.6643; recon_loss: 0.8726; valid_recon_loss: 0.5677
# Epoch-8; D_loss_gauss: 1.325; G_loss: 0.6671; recon_loss: 0.4802; valid_recon_loss: 0.6329
# Epoch-9; D_loss_gauss: 1.357; G_loss: 0.651; recon_loss: 0.5638; valid_recon_loss: 0.5853
# Epoch-10; D_loss_gauss: 1.373; G_loss: 0.6236; recon_loss: 0.4868; valid_recon_loss: 0.4882
# Epoch-11; D_loss_gauss: 1.492; G_loss: 0.6127; recon_loss: 0.5183; valid_recon_loss: 0.4964
# Epoch-12; D_loss_gauss: 1.352; G_loss: 0.6034; recon_loss: 0.489; valid_recon_loss: 0.5886
# Epoch-13; D_loss_gauss: 1.433; G_loss: 0.5953; recon_loss: 0.5626; valid_recon_loss: 0.5347
# Epoch-14; D_loss_gauss: 1.389; G_loss: 0.6023; recon_loss: 0.451; valid_recon_loss: 0.5245
# Epoch-15; D_loss_gauss: 1.443; G_loss: 0.6; recon_loss: 0.4657; valid_recon_loss: 0.5394
# Epoch-16; D_loss_gauss: 1.42; G_loss: 0.6138; recon_loss: 0.4683; valid_recon_loss: 0.5479
# Epoch-17; D_loss_gauss: 1.407; G_loss: 0.6197; recon_loss: 0.4618; valid_recon_loss: 0.5767
# Epoch-18; D_loss_gauss: 1.287; G_loss: 0.6159; recon_loss: 0.4634; valid_recon_loss: 0.5546
# Epoch-19; D_loss_gauss: 1.286; G_loss: 0.6057; recon_loss: 0.4582; valid_recon_loss: 0.5364
# Epoch-20; D_loss_gauss: 1.366; G_loss: 0.5981; recon_loss: 0.4418; valid_recon_loss: 0.5254
# Epoch-21; D_loss_gauss: 1.427; G_loss: 0.6038; recon_loss: 0.4491; valid_recon_loss: 0.5148
# Epoch-22; D_loss_gauss: 1.507; G_loss: 0.5927; recon_loss: 0.4323; valid_recon_loss: 0.5286
# Epoch-23; D_loss_gauss: 1.445; G_loss: 0.589; recon_loss: 0.4379; valid_recon_loss: 0.525
# Epoch-24; D_loss_gauss: 1.441; G_loss: 0.5786; recon_loss: 0.4395; valid_recon_loss: 0.5153
# Epoch-25; D_loss_gauss: 1.502; G_loss: 0.5651; recon_loss: 0.4354; valid_recon_loss: 0.5333
# Epoch-26; D_loss_gauss: 1.44; G_loss: 0.5699; recon_loss: 0.4352; valid_recon_loss: 0.5168
# Epoch-27; D_loss_gauss: 1.409; G_loss: 0.564; recon_loss: 0.4316; valid_recon_loss: 0.5342
# Epoch-28; D_loss_gauss: 1.432; G_loss: 0.5691; recon_loss: 0.4282; valid_recon_loss: 0.5249
# Epoch-29; D_loss_gauss: 1.379; G_loss: 0.5555; recon_loss: 0.4285; valid_recon_loss: 0.5163
# Epoch-30; D_loss_gauss: 1.469; G_loss: 0.5435; recon_loss: 0.4266; valid_recon_loss: 0.5034
# Epoch-31; D_loss_gauss: 1.498; G_loss: 0.5499; recon_loss: 0.4287; valid_recon_loss: 0.5213
# Epoch-32; D_loss_gauss: 1.395; G_loss: 0.5487; recon_loss: 0.4231; valid_recon_loss: 0.5448
# Epoch-33; D_loss_gauss: 1.457; G_loss: 0.5369; recon_loss: 0.4295; valid_recon_loss: 0.5249
# Epoch-34; D_loss_gauss: 1.456; G_loss: 0.529; recon_loss: 0.4208; valid_recon_loss: 0.5211
# Epoch-35; D_loss_gauss: 1.479; G_loss: 0.5201; recon_loss: 0.4204; valid_recon_loss: 0.524
# Epoch-36; D_loss_gauss: 1.441; G_loss: 0.5358; recon_loss: 0.418; valid_recon_loss: 0.5478
# Epoch-37; D_loss_gauss: 1.519; G_loss: 0.5317; recon_loss: 0.429; valid_recon_loss: 0.5359
# Epoch-38; D_loss_gauss: 1.473; G_loss: 0.5194; recon_loss: 0.4202; valid_recon_loss: 0.5076
# Epoch-39; D_loss_gauss: 1.479; G_loss: 0.5133; recon_loss: 0.4237; valid_recon_loss: 0.5172
# Epoch-40; D_loss_gauss: 1.45; G_loss: 0.5154; recon_loss: 0.4216; valid_recon_loss: 0.5194
# Epoch-41; D_loss_gauss: 1.492; G_loss: 0.5246; recon_loss: 0.4182; valid_recon_loss: 0.5319
# Epoch-42; D_loss_gauss: 1.508; G_loss: 0.4944; recon_loss: 0.4252; valid_recon_loss: 0.5086
# Epoch-43; D_loss_gauss: 1.507; G_loss: 0.4678; recon_loss: 0.4184; valid_recon_loss: 0.4937
# Epoch-44; D_loss_gauss: 1.546; G_loss: 0.4734; recon_loss: 0.4259; valid_recon_loss: 0.4875
# Epoch-45; D_loss_gauss: 1.644; G_loss: 0.4931; recon_loss: 0.4216; valid_recon_loss: 0.5142
# Epoch-46; D_loss_gauss: 1.581; G_loss: 0.4996; recon_loss: 0.4126; valid_recon_loss: 0.542
# Epoch-47; D_loss_gauss: 1.575; G_loss: 0.4952; recon_loss: 0.415; valid_recon_loss: 0.5207
# Epoch-48; D_loss_gauss: 1.537; G_loss: 0.4676; recon_loss: 0.4155; valid_recon_loss: 0.5086
# Epoch-49; D_loss_gauss: 1.597; G_loss: 0.4601; recon_loss: 0.4143; valid_recon_loss: 0.5119
# Epoch-50; D_loss_gauss: 1.594; G_loss: 0.4646; recon_loss: 0.409; valid_recon_loss: 0.5068
# Epoch-51; D_loss_gauss: 1.575; G_loss: 0.459; recon_loss: 0.4094; valid_recon_loss: 0.5186
# Epoch-52; D_loss_gauss: 1.669; G_loss: 0.4755; recon_loss: 0.4112; valid_recon_loss: 0.5112
# Epoch-53; D_loss_gauss: 1.673; G_loss: 0.4396; recon_loss: 0.4157; valid_recon_loss: 0.514
# Epoch-54; D_loss_gauss: 1.609; G_loss: 0.4165; recon_loss: 0.4071; valid_recon_loss: 0.5092
# Epoch-55; D_loss_gauss: 1.693; G_loss: 0.4113; recon_loss: 0.4147; valid_recon_loss: 0.481
# Epoch-56; D_loss_gauss: 1.626; G_loss: 0.4284; recon_loss: 0.4134; valid_recon_loss: 0.5038
# Epoch-57; D_loss_gauss: 1.62; G_loss: 0.4328; recon_loss: 0.4055; valid_recon_loss: 0.5096
# Epoch-58; D_loss_gauss: 1.703; G_loss: 0.4314; recon_loss: 0.4126; valid_recon_loss: 0.5205
# Epoch-59; D_loss_gauss: 1.735; G_loss: 0.4108; recon_loss: 0.403; valid_recon_loss: 0.513
# Epoch-60; D_loss_gauss: 1.801; G_loss: 0.3712; recon_loss: 0.4009; valid_recon_loss: 0.4977
# Epoch-61; D_loss_gauss: 1.808; G_loss: 0.381; recon_loss: 0.405; valid_recon_loss: 0.5243
# Epoch-62; D_loss_gauss: 1.804; G_loss: 0.3638; recon_loss: 0.3989; valid_recon_loss: 0.5007
# Epoch-63; D_loss_gauss: 1.829; G_loss: 0.3387; recon_loss: 0.3984; valid_recon_loss: 0.5013
# Epoch-64; D_loss_gauss: 1.988; G_loss: 0.3348; recon_loss: 0.4019; valid_recon_loss: 0.4805
# Epoch-65; D_loss_gauss: 1.93; G_loss: 0.3335; recon_loss: 0.3964; valid_recon_loss: 0.513
# Epoch-66; D_loss_gauss: 2.008; G_loss: 0.3086; recon_loss: 0.3822; valid_recon_loss: 0.495
# Epoch-67; D_loss_gauss: 1.948; G_loss: 0.2963; recon_loss: 0.3966; valid_recon_loss: 0.5003
# Epoch-68; D_loss_gauss: 2.086; G_loss: 0.312; recon_loss: 0.3797; valid_recon_loss: 0.5037
# Epoch-69; D_loss_gauss: 2.117; G_loss: 0.2974; recon_loss: 0.3753; valid_recon_loss: 0.4885
# Epoch-70; D_loss_gauss: 2.034; G_loss: 0.2942; recon_loss: 0.3964; valid_recon_loss: 0.545
# Epoch-71; D_loss_gauss: 2.085; G_loss: 0.2944; recon_loss: 0.3625; valid_recon_loss: 0.5143
# Epoch-72; D_loss_gauss: 2.119; G_loss: 0.2703; recon_loss: 0.3905; valid_recon_loss: 0.5025
# Epoch-73; D_loss_gauss: 2.154; G_loss: 0.2474; recon_loss: 0.374; valid_recon_loss: 0.465
# Epoch-74; D_loss_gauss: 2.195; G_loss: 0.2768; recon_loss: 0.3691; valid_recon_loss: 0.4873
# Epoch-75; D_loss_gauss: 2.111; G_loss: 0.2536; recon_loss: 0.367; valid_recon_loss: 0.5167
# Epoch-76; D_loss_gauss: 2.172; G_loss: 0.2669; recon_loss: 0.3582; valid_recon_loss: 0.5385
# Epoch-77; D_loss_gauss: 2.194; G_loss: 0.2304; recon_loss: 0.3952; valid_recon_loss: 0.4847
# Epoch-78; D_loss_gauss: 2.389; G_loss: 0.2574; recon_loss: 0.3764; valid_recon_loss: 0.4801
# Epoch-79; D_loss_gauss: 2.118; G_loss: 0.2582; recon_loss: 0.3513; valid_recon_loss: 0.5223
# Epoch-80; D_loss_gauss: 2.181; G_loss: 0.2679; recon_loss: 0.3769; valid_recon_loss: 0.5371
# Epoch-81; D_loss_gauss: 2.174; G_loss: 0.262; recon_loss: 0.3727; valid_recon_loss: 0.5058
# Epoch-82; D_loss_gauss: 2.099; G_loss: 0.2441; recon_loss: 0.3529; valid_recon_loss: 0.5312
# Epoch-83; D_loss_gauss: 2.277; G_loss: 0.2547; recon_loss: 0.359; valid_recon_loss: 0.4834
# Epoch-84; D_loss_gauss: 2.17; G_loss: 0.2569; recon_loss: 0.3638; valid_recon_loss: 0.5529
# Epoch-85; D_loss_gauss: 2.125; G_loss: 0.2743; recon_loss: 0.3578; valid_recon_loss: 0.5018
# Epoch-86; D_loss_gauss: 2.063; G_loss: 0.2862; recon_loss: 0.3456; valid_recon_loss: 0.5564
# Epoch-87; D_loss_gauss: 1.914; G_loss: 0.3047; recon_loss: 0.3587; valid_recon_loss: 0.5362
# Epoch-88; D_loss_gauss: 1.939; G_loss: 0.2957; recon_loss: 0.356; valid_recon_loss: 0.5584
# Epoch-89; D_loss_gauss: 1.993; G_loss: 0.282; recon_loss: 0.3425; valid_recon_loss: 0.5211
# Epoch-90; D_loss_gauss: 2.19; G_loss: 0.2504; recon_loss: 0.3497; valid_recon_loss: 0.4527
# Epoch-91; D_loss_gauss: 2.124; G_loss: 0.2748; recon_loss: 0.3557; valid_recon_loss: 0.5062
# Epoch-92; D_loss_gauss: 2.073; G_loss: 0.2743; recon_loss: 0.3365; valid_recon_loss: 0.5173
# Epoch-93; D_loss_gauss: 2.036; G_loss: 0.2541; recon_loss: 0.3425; valid_recon_loss: 0.5182
# Epoch-94; D_loss_gauss: 2.015; G_loss: 0.2899; recon_loss: 0.3548; valid_recon_loss: 0.5307
# Epoch-95; D_loss_gauss: 2.058; G_loss: 0.2758; recon_loss: 0.342; valid_recon_loss: 0.5375
# Epoch-96; D_loss_gauss: 2.025; G_loss: 0.2972; recon_loss: 0.3517; valid_recon_loss: 0.5393
# Epoch-97; D_loss_gauss: 2.113; G_loss: 0.2679; recon_loss: 0.3474; valid_recon_loss: 0.4911
# Epoch-98; D_loss_gauss: 2.137; G_loss: 0.2354; recon_loss: 0.3388; valid_recon_loss: 0.4704
# Epoch-99; D_loss_gauss: 2.134; G_loss: 0.256; recon_loss: 0.3368; valid_recon_loss: 0.4875
# Epoch-100; D_loss_gauss: 2.262; G_loss: 0.2613; recon_loss: 0.3367; valid_recon_loss: 0.4934
# Epoch-101; D_loss_gauss: 2.244; G_loss: 0.2539; recon_loss: 0.3315; valid_recon_loss: 0.504
# Epoch-102; D_loss_gauss: 2.123; G_loss: 0.2488; recon_loss: 0.3372; valid_recon_loss: 0.532
# Epoch-103; D_loss_gauss: 2.241; G_loss: 0.2703; recon_loss: 0.3095; valid_recon_loss: 0.5136
# Epoch-104; D_loss_gauss: 2.326; G_loss: 0.2284; recon_loss: 0.3486; valid_recon_loss: 0.5209
# Epoch-105; D_loss_gauss: 2.321; G_loss: 0.2232; recon_loss: 0.3259; valid_recon_loss: 0.579
# Epoch-106; D_loss_gauss: 2.219; G_loss: 0.216; recon_loss: 0.3347; valid_recon_loss: 0.5451
# Epoch-107; D_loss_gauss: 2.529; G_loss: 0.1977; recon_loss: 0.3267; valid_recon_loss: 0.4969
# Epoch-108; D_loss_gauss: 2.564; G_loss: 0.1696; recon_loss: 0.317; valid_recon_loss: 0.5
# Epoch-109; D_loss_gauss: 2.621; G_loss: 0.1804; recon_loss: 0.3257; valid_recon_loss: 0.5066
# Epoch-110; D_loss_gauss: 2.628; G_loss: 0.1698; recon_loss: 0.3336; valid_recon_loss: 0.5865
# Epoch-111; D_loss_gauss: 2.589; G_loss: 0.1702; recon_loss: 0.3224; valid_recon_loss: 0.5697
# Epoch-112; D_loss_gauss: 2.656; G_loss: 0.1528; recon_loss: 0.3161; valid_recon_loss: 0.5182
# Epoch-113; D_loss_gauss: 2.725; G_loss: 0.1301; recon_loss: 0.3308; valid_recon_loss: 0.505
# Epoch-114; D_loss_gauss: 2.726; G_loss: 0.143; recon_loss: 0.3046; valid_recon_loss: 0.5328
# Epoch-115; D_loss_gauss: 2.779; G_loss: 0.1377; recon_loss: 0.3078; valid_recon_loss: 0.549
# Epoch-116; D_loss_gauss: 2.809; G_loss: 0.1342; recon_loss: 0.3278; valid_recon_loss: 0.4961
# Epoch-117; D_loss_gauss: 2.838; G_loss: 0.137; recon_loss: 0.3249; valid_recon_loss: 0.4753
# Epoch-118; D_loss_gauss: 2.809; G_loss: 0.1491; recon_loss: 0.3167; valid_recon_loss: 0.554
# Epoch-119; D_loss_gauss: 2.941; G_loss: 0.1351; recon_loss: 0.3239; valid_recon_loss: 0.4853
# Epoch-120; D_loss_gauss: 2.861; G_loss: 0.1366; recon_loss: 0.3279; valid_recon_loss: 0.5484
# Epoch-121; D_loss_gauss: 2.976; G_loss: 0.1331; recon_loss: 0.3201; valid_recon_loss: 0.5154
# Epoch-122; D_loss_gauss: 2.81; G_loss: 0.1397; recon_loss: 0.3045; valid_recon_loss: 0.5428
# Epoch-123; D_loss_gauss: 2.747; G_loss: 0.158; recon_loss: 0.3189; valid_recon_loss: 0.5251
# Epoch-124; D_loss_gauss: 2.867; G_loss: 0.1471; recon_loss: 0.315; valid_recon_loss: 0.5472
# Epoch-125; D_loss_gauss: 2.793; G_loss: 0.1581; recon_loss: 0.3003; valid_recon_loss: 0.5795
# Epoch-126; D_loss_gauss: 2.873; G_loss: 0.1514; recon_loss: 0.3003; valid_recon_loss: 0.5399
# Epoch-127; D_loss_gauss: 2.717; G_loss: 0.1453; recon_loss: 0.3071; valid_recon_loss: 0.5315
# Epoch-128; D_loss_gauss: 2.635; G_loss: 0.1553; recon_loss: 0.2931; valid_recon_loss: 0.5308
# Epoch-129; D_loss_gauss: 2.718; G_loss: 0.165; recon_loss: 0.3003; valid_recon_loss: 0.5216
# Epoch-130; D_loss_gauss: 2.711; G_loss: 0.1625; recon_loss: 0.2918; valid_recon_loss: 0.51
# Epoch-131; D_loss_gauss: 2.625; G_loss: 0.1577; recon_loss: 0.2977; valid_recon_loss: 0.5332
# Epoch-132; D_loss_gauss: 2.612; G_loss: 0.1638; recon_loss: 0.3055; valid_recon_loss: 0.5367
# Epoch-133; D_loss_gauss: 2.723; G_loss: 0.1703; recon_loss: 0.2905; valid_recon_loss: 0.5779
# Epoch-134; D_loss_gauss: 2.82; G_loss: 0.1459; recon_loss: 0.2886; valid_recon_loss: 0.5442
# Epoch-135; D_loss_gauss: 2.844; G_loss: 0.1497; recon_loss: 0.2957; valid_recon_loss: 0.5839
# Epoch-136; D_loss_gauss: 2.913; G_loss: 0.1203; recon_loss: 0.288; valid_recon_loss: 0.5182
# Epoch-137; D_loss_gauss: 2.953; G_loss: 0.1296; recon_loss: 0.2792; valid_recon_loss: 0.4821
# Epoch-138; D_loss_gauss: 2.968; G_loss: 0.1403; recon_loss: 0.2727; valid_recon_loss: 0.5073
# Epoch-139; D_loss_gauss: 3.053; G_loss: 0.1196; recon_loss: 0.2786; valid_recon_loss: 0.5409
# Epoch-140; D_loss_gauss: 3.013; G_loss: 0.1186; recon_loss: 0.2751; valid_recon_loss: 0.5915
# Epoch-141; D_loss_gauss: 3.059; G_loss: 0.1147; recon_loss: 0.2867; valid_recon_loss: 0.5806
# Epoch-142; D_loss_gauss: 3.011; G_loss: 0.1208; recon_loss: 0.2782; valid_recon_loss: 0.5885
# Epoch-143; D_loss_gauss: 2.953; G_loss: 0.1346; recon_loss: 0.2708; valid_recon_loss: 0.5614
# Epoch-144; D_loss_gauss: 3.117; G_loss: 0.09421; recon_loss: 0.3149; valid_recon_loss: 0.556
# Epoch-145; D_loss_gauss: 3.063; G_loss: 0.1051; recon_loss: 0.3073; valid_recon_loss: 0.5839
# Epoch-146; D_loss_gauss: 3.109; G_loss: 0.1146; recon_loss: 0.2894; valid_recon_loss: 0.6079
# Epoch-147; D_loss_gauss: 3.005; G_loss: 0.108; recon_loss: 0.3018; valid_recon_loss: 0.5189
# Epoch-148; D_loss_gauss: 3.08; G_loss: 0.1166; recon_loss: 0.2794; valid_recon_loss: 0.5991
# Epoch-149; D_loss_gauss: 2.952; G_loss: 0.1202; recon_loss: 0.3017; valid_recon_loss: 0.6037
# Epoch-150; D_loss_gauss: 2.839; G_loss: 0.1311; recon_loss: 0.2774; valid_recon_loss: 0.558
# Epoch-151; D_loss_gauss: 2.907; G_loss: 0.1355; recon_loss: 0.2812; valid_recon_loss: 0.5604
# Epoch-152; D_loss_gauss: 2.786; G_loss: 0.1379; recon_loss: 0.2468; valid_recon_loss: 0.5262
# Epoch-153; D_loss_gauss: 2.669; G_loss: 0.1362; recon_loss: 0.2578; valid_recon_loss: 0.5061
# Epoch-154; D_loss_gauss: 2.759; G_loss: 0.1472; recon_loss: 0.2697; valid_recon_loss: 0.5362
# Epoch-155; D_loss_gauss: 2.647; G_loss: 0.1588; recon_loss: 0.267; valid_recon_loss: 0.6469
# Epoch-156; D_loss_gauss: 2.655; G_loss: 0.1513; recon_loss: 0.2701; valid_recon_loss: 0.5636
# Epoch-157; D_loss_gauss: 2.689; G_loss: 0.1532; recon_loss: 0.2694; valid_recon_loss: 0.468
# Epoch-158; D_loss_gauss: 2.726; G_loss: 0.1819; recon_loss: 0.2526; valid_recon_loss: 0.5288
# Epoch-159; D_loss_gauss: 2.675; G_loss: 0.1442; recon_loss: 0.2578; valid_recon_loss: 0.555
# Epoch-160; D_loss_gauss: 2.564; G_loss: 0.1544; recon_loss: 0.2425; valid_recon_loss: 0.572
# Epoch-161; D_loss_gauss: 2.614; G_loss: 0.1704; recon_loss: 0.2593; valid_recon_loss: 0.5563
# Epoch-162; D_loss_gauss: 2.66; G_loss: 0.1528; recon_loss: 0.2383; valid_recon_loss: 0.5518
# Epoch-163; D_loss_gauss: 2.825; G_loss: 0.1478; recon_loss: 0.2372; valid_recon_loss: 0.5374
# Epoch-164; D_loss_gauss: 2.752; G_loss: 0.1476; recon_loss: 0.2257; valid_recon_loss: 0.5458
# Epoch-165; D_loss_gauss: 2.741; G_loss: 0.1505; recon_loss: 0.2205; valid_recon_loss: 0.5756
# Epoch-166; D_loss_gauss: 2.715; G_loss: 0.1499; recon_loss: 0.2245; valid_recon_loss: 0.6356
# Epoch-167; D_loss_gauss: 2.744; G_loss: 0.1587; recon_loss: 0.2149; valid_recon_loss: 0.5116
# Epoch-168; D_loss_gauss: 2.807; G_loss: 0.1431; recon_loss: 0.2006; valid_recon_loss: 0.5965
# Epoch-169; D_loss_gauss: 3.025; G_loss: 0.1248; recon_loss: 0.2384; valid_recon_loss: 0.5804
# Epoch-170; D_loss_gauss: 3.158; G_loss: 0.1119; recon_loss: 0.2141; valid_recon_loss: 0.5501
# Epoch-171; D_loss_gauss: 2.957; G_loss: 0.1376; recon_loss: 0.2365; valid_recon_loss: 0.6501
# Epoch-172; D_loss_gauss: 2.936; G_loss: 0.1161; recon_loss: 0.2237; valid_recon_loss: 0.584
# Epoch-173; D_loss_gauss: 3.132; G_loss: 0.122; recon_loss: 0.2194; valid_recon_loss: 0.56
# Epoch-174; D_loss_gauss: 3.016; G_loss: 0.1168; recon_loss: 0.2286; valid_recon_loss: 0.5916
# Epoch-175; D_loss_gauss: 3.102; G_loss: 0.1055; recon_loss: 0.2169; valid_recon_loss: 0.6058
# Epoch-176; D_loss_gauss: 3.036; G_loss: 0.124; recon_loss: 0.2163; valid_recon_loss: 0.6616
# Epoch-177; D_loss_gauss: 2.959; G_loss: 0.1233; recon_loss: 0.2323; valid_recon_loss: 0.6148
# Epoch-178; D_loss_gauss: 2.987; G_loss: 0.1258; recon_loss: 0.2006; valid_recon_loss: 0.6973
# Epoch-179; D_loss_gauss: 2.971; G_loss: 0.1274; recon_loss: 0.2184; valid_recon_loss: 0.595
# Epoch-180; D_loss_gauss: 3.008; G_loss: 0.132; recon_loss: 0.2307; valid_recon_loss: 0.6289
# Epoch-181; D_loss_gauss: 3.076; G_loss: 0.1068; recon_loss: 0.2467; valid_recon_loss: 0.685
# Epoch-182; D_loss_gauss: 3.059; G_loss: 0.1221; recon_loss: 0.2117; valid_recon_loss: 0.519
# Epoch-183; D_loss_gauss: 3.108; G_loss: 0.1304; recon_loss: 0.1918; valid_recon_loss: 0.5835
# Epoch-184; D_loss_gauss: 3.203; G_loss: 0.1212; recon_loss: 0.2046; valid_recon_loss: 0.5703
# Epoch-185; D_loss_gauss: 3.3; G_loss: 0.09942; recon_loss: 0.2158; valid_recon_loss: 0.5062
# Epoch-186; D_loss_gauss: 3.451; G_loss: 0.08439; recon_loss: 0.2248; valid_recon_loss: 0.6567
# Epoch-187; D_loss_gauss: 3.46; G_loss: 0.1012; recon_loss: 0.226; valid_recon_loss: 0.5605
# Epoch-188; D_loss_gauss: 3.534; G_loss: 0.09066; recon_loss: 0.2315; valid_recon_loss: 0.6574
# Epoch-189; D_loss_gauss: 3.607; G_loss: 0.08645; recon_loss: 0.1984; valid_recon_loss: 0.5739
# Epoch-190; D_loss_gauss: 3.443; G_loss: 0.09154; recon_loss: 0.2488; valid_recon_loss: 0.5765
# Epoch-191; D_loss_gauss: 3.39; G_loss: 0.09381; recon_loss: 0.2036; valid_recon_loss: 0.597
# Epoch-192; D_loss_gauss: 3.316; G_loss: 0.09193; recon_loss: 0.2105; valid_recon_loss: 0.6617
# Epoch-193; D_loss_gauss: 3.327; G_loss: 0.105; recon_loss: 0.2008; valid_recon_loss: 0.7778
# Epoch-194; D_loss_gauss: 3.226; G_loss: 0.1034; recon_loss: 0.1865; valid_recon_loss: 0.7034
# Epoch-195; D_loss_gauss: 3.08; G_loss: 0.1172; recon_loss: 0.185; valid_recon_loss: 0.5288
# Epoch-196; D_loss_gauss: 3.373; G_loss: 0.1083; recon_loss: 0.2261; valid_recon_loss: 0.6083
# Epoch-197; D_loss_gauss: 3.283; G_loss: 0.09666; recon_loss: 0.2057; valid_recon_loss: 0.5865
# Epoch-198; D_loss_gauss: 3.258; G_loss: 0.08851; recon_loss: 0.1979; valid_recon_loss: 0.5699
# Epoch-199; D_loss_gauss: 3.252; G_loss: 0.1033; recon_loss: 0.1834; valid_recon_loss: 0.5925
# Epoch-200; D_loss_gauss: 3.463; G_loss: 0.08857; recon_loss: 0.1934; valid_recon_loss: 0.6096
# Epoch-201; D_loss_gauss: 3.293; G_loss: 0.08494; recon_loss: 0.1981; valid_recon_loss: 0.5932
# Epoch-202; D_loss_gauss: 3.326; G_loss: 0.1109; recon_loss: 0.2183; valid_recon_loss: 0.7799
# Epoch-203; D_loss_gauss: 3.311; G_loss: 0.09401; recon_loss: 0.2482; valid_recon_loss: 0.5695
# Epoch-204; D_loss_gauss: 3.412; G_loss: 0.09168; recon_loss: 0.164; valid_recon_loss: 0.6872
# Epoch-205; D_loss_gauss: 3.355; G_loss: 0.0895; recon_loss: 0.1852; valid_recon_loss: 0.5112
# Epoch-206; D_loss_gauss: 3.314; G_loss: 0.08963; recon_loss: 0.2449; valid_recon_loss: 0.5674
# Epoch-207; D_loss_gauss: 3.163; G_loss: 0.1034; recon_loss: 0.1804; valid_recon_loss: 0.5852
# Epoch-208; D_loss_gauss: 3.041; G_loss: 0.09676; recon_loss: 0.1935; valid_recon_loss: 0.6546
# Epoch-209; D_loss_gauss: 3.198; G_loss: 0.1164; recon_loss: 0.1784; valid_recon_loss: 0.7901
# Epoch-210; D_loss_gauss: 3.218; G_loss: 0.1489; recon_loss: 0.2058; valid_recon_loss: 0.4871
# Epoch-211; D_loss_gauss: 2.992; G_loss: 0.1102; recon_loss: 0.2002; valid_recon_loss: 0.8959
# Epoch-212; D_loss_gauss: 2.848; G_loss: 0.1243; recon_loss: 0.1855; valid_recon_loss: 0.7
# Epoch-213; D_loss_gauss: 3.036; G_loss: 0.1293; recon_loss: 0.1713; valid_recon_loss: 0.7627
# Epoch-214; D_loss_gauss: 2.871; G_loss: 0.1377; recon_loss: 0.1659; valid_recon_loss: 0.7002
# Epoch-215; D_loss_gauss: 2.776; G_loss: 0.1517; recon_loss: 0.165; valid_recon_loss: 0.6779
# Epoch-216; D_loss_gauss: 2.729; G_loss: 0.129; recon_loss: 0.182; valid_recon_loss: 0.8732
# Epoch-217; D_loss_gauss: 2.788; G_loss: 0.1412; recon_loss: 0.167; valid_recon_loss: 0.857
# Epoch-218; D_loss_gauss: 3.061; G_loss: 0.1168; recon_loss: 0.2608; valid_recon_loss: 0.749
# Epoch-219; D_loss_gauss: 3.147; G_loss: 0.09109; recon_loss: 0.171; valid_recon_loss: 0.6681
# Epoch-220; D_loss_gauss: 2.985; G_loss: 0.09665; recon_loss: 0.2371; valid_recon_loss: 0.7502
# Epoch-221; D_loss_gauss: 3.074; G_loss: 0.1103; recon_loss: 0.1675; valid_recon_loss: 0.7651
# Epoch-222; D_loss_gauss: 3.1; G_loss: 0.09972; recon_loss: 0.1805; valid_recon_loss: 0.7815
# Epoch-223; D_loss_gauss: 3.196; G_loss: 0.118; recon_loss: 0.1704; valid_recon_loss: 0.4579
# Epoch-224; D_loss_gauss: 3.126; G_loss: 0.1079; recon_loss: 0.1497; valid_recon_loss: 0.6198
# Epoch-225; D_loss_gauss: 3.221; G_loss: 0.1045; recon_loss: 0.1804; valid_recon_loss: 0.6245
# Epoch-226; D_loss_gauss: 3.131; G_loss: 0.1114; recon_loss: 0.1686; valid_recon_loss: 0.6541
# Epoch-227; D_loss_gauss: 3.165; G_loss: 0.1127; recon_loss: 0.1642; valid_recon_loss: 0.7842
# Epoch-228; D_loss_gauss: 3.167; G_loss: 0.09907; recon_loss: 0.1718; valid_recon_loss: 0.6675
# Epoch-229; D_loss_gauss: 3.13; G_loss: 0.1042; recon_loss: 0.1544; valid_recon_loss: 0.7798
# Epoch-230; D_loss_gauss: 3.127; G_loss: 0.1044; recon_loss: 0.1306; valid_recon_loss: 0.7678
# Epoch-231; D_loss_gauss: 3.054; G_loss: 0.0912; recon_loss: 0.2135; valid_recon_loss: 0.8134
# Epoch-232; D_loss_gauss: 2.966; G_loss: 0.102; recon_loss: 0.1476; valid_recon_loss: 0.8035
# Epoch-233; D_loss_gauss: 3.035; G_loss: 0.1101; recon_loss: 0.1405; valid_recon_loss: 1.182
# Epoch-234; D_loss_gauss: 3.104; G_loss: 0.09669; recon_loss: 0.4637; valid_recon_loss: 1.427
# Epoch-235; D_loss_gauss: 3.094; G_loss: 0.08877; recon_loss: 0.1752; valid_recon_loss: 0.7843
# Epoch-236; D_loss_gauss: 3.25; G_loss: 0.08381; recon_loss: 0.1741; valid_recon_loss: 1.024
# Epoch-237; D_loss_gauss: 3.395; G_loss: 0.08524; recon_loss: 0.1564; valid_recon_loss: 0.8671
# Epoch-238; D_loss_gauss: 3.332; G_loss: 0.09851; recon_loss: 0.2645; valid_recon_loss: 0.6699
# Epoch-239; D_loss_gauss: 3.39; G_loss: 0.07885; recon_loss: 0.1533; valid_recon_loss: 1.004
# Epoch-240; D_loss_gauss: 3.273; G_loss: 0.08817; recon_loss: 0.1656; valid_recon_loss: 0.8473
# Epoch-241; D_loss_gauss: 3.281; G_loss: 0.09377; recon_loss: 0.2172; valid_recon_loss: 0.6423
# Epoch-242; D_loss_gauss: 3.424; G_loss: 0.0706; recon_loss: 0.1471; valid_recon_loss: 0.9148
# Epoch-243; D_loss_gauss: 3.638; G_loss: 0.07739; recon_loss: 0.1746; valid_recon_loss: 0.7845
# Epoch-244; D_loss_gauss: 3.841; G_loss: 0.04696; recon_loss: 0.1985; valid_recon_loss: 0.7297
# Epoch-245; D_loss_gauss: 3.823; G_loss: 0.05586; recon_loss: 0.1272; valid_recon_loss: 0.6318
# Epoch-246; D_loss_gauss: 3.812; G_loss: 0.04411; recon_loss: 0.1474; valid_recon_loss: 1.155
# Epoch-247; D_loss_gauss: 3.951; G_loss: 0.04336; recon_loss: 0.1559; valid_recon_loss: 0.7764
# Epoch-248; D_loss_gauss: 3.901; G_loss: 0.05019; recon_loss: 0.146; valid_recon_loss: 1.012
# Epoch-249; D_loss_gauss: 4.011; G_loss: 0.04393; recon_loss: 0.14; valid_recon_loss: 1.042
# Epoch-250; D_loss_gauss: 4.109; G_loss: 0.04604; recon_loss: 0.1246; valid_recon_loss: 0.7302
# Epoch-251; D_loss_gauss: 3.998; G_loss: 0.03843; recon_loss: 0.1415; valid_recon_loss: 1.08
# Epoch-252; D_loss_gauss: 3.964; G_loss: 0.04181; recon_loss: 0.1323; valid_recon_loss: 1.288
# Epoch-253; D_loss_gauss: 3.97; G_loss: 0.05222; recon_loss: 0.1733; valid_recon_loss: 0.9523
# Epoch-254; D_loss_gauss: 3.885; G_loss: 0.06613; recon_loss: 0.1441; valid_recon_loss: 1.343
# Epoch-255; D_loss_gauss: 3.87; G_loss: 0.04496; recon_loss: 0.1542; valid_recon_loss: 1.039
# Epoch-256; D_loss_gauss: 4.261; G_loss: 0.04418; recon_loss: 0.1408; valid_recon_loss: 1.342
# Epoch-257; D_loss_gauss: 4.313; G_loss: 0.04797; recon_loss: 0.1235; valid_recon_loss: 1.05
# Epoch-258; D_loss_gauss: 4.233; G_loss: 0.04974; recon_loss: 0.233; valid_recon_loss: 1.156
# Epoch-259; D_loss_gauss: 3.947; G_loss: 0.05327; recon_loss: 0.1375; valid_recon_loss: 0.9426
# Epoch-260; D_loss_gauss: 3.877; G_loss: 0.06923; recon_loss: 0.1519; valid_recon_loss: 0.9476
# Epoch-261; D_loss_gauss: 3.92; G_loss: 0.05618; recon_loss: 0.1555; valid_recon_loss: 0.9749
# Epoch-262; D_loss_gauss: 3.777; G_loss: 0.05509; recon_loss: 0.1336; valid_recon_loss: 0.9147
# Epoch-263; D_loss_gauss: 3.738; G_loss: 0.06974; recon_loss: 0.1229; valid_recon_loss: 1.055
# Epoch-264; D_loss_gauss: 3.644; G_loss: 0.07407; recon_loss: 0.1694; valid_recon_loss: 1.272
# Epoch-265; D_loss_gauss: 3.604; G_loss: 0.07509; recon_loss: 0.1063; valid_recon_loss: 1.23
# Epoch-266; D_loss_gauss: 3.532; G_loss: 0.07289; recon_loss: 0.1198; valid_recon_loss: 1.704
# Epoch-267; D_loss_gauss: 3.579; G_loss: 0.06315; recon_loss: 0.1334; valid_recon_loss: 1.58
# Epoch-268; D_loss_gauss: 3.643; G_loss: 0.04931; recon_loss: 0.1265; valid_recon_loss: 1.437
# Epoch-269; D_loss_gauss: 3.366; G_loss: 0.07518; recon_loss: 0.1388; valid_recon_loss: 1.284
# Epoch-270; D_loss_gauss: 3.451; G_loss: 0.0668; recon_loss: 0.1194; valid_recon_loss: 0.9755
# Epoch-271; D_loss_gauss: 3.482; G_loss: 0.07292; recon_loss: 0.1018; valid_recon_loss: 1.357
# Epoch-272; D_loss_gauss: 3.583; G_loss: 0.07386; recon_loss: 0.1068; valid_recon_loss: 1.363
# Epoch-273; D_loss_gauss: 3.655; G_loss: 0.07246; recon_loss: 0.1531; valid_recon_loss: 1.162
# Epoch-274; D_loss_gauss: 3.658; G_loss: 0.06908; recon_loss: 0.1152; valid_recon_loss: 1.349
# Epoch-275; D_loss_gauss: 3.816; G_loss: 0.08167; recon_loss: 0.1149; valid_recon_loss: 1.681
# Epoch-276; D_loss_gauss: 3.887; G_loss: 0.05692; recon_loss: 0.1323; valid_recon_loss: 1.271
# Epoch-277; D_loss_gauss: 3.987; G_loss: 0.0386; recon_loss: 0.1094; valid_recon_loss: 1.47
# Epoch-278; D_loss_gauss: 4.128; G_loss: 0.05339; recon_loss: 0.1032; valid_recon_loss: 0.9518
# Epoch-279; D_loss_gauss: 4.014; G_loss: 0.04959; recon_loss: 0.1056; valid_recon_loss: 1.298
# Epoch-280; D_loss_gauss: 4.056; G_loss: 0.04108; recon_loss: 0.1249; valid_recon_loss: 1.046
# Epoch-281; D_loss_gauss: 4.378; G_loss: 0.03289; recon_loss: 0.3302; valid_recon_loss: 1.129
# Epoch-282; D_loss_gauss: 4.457; G_loss: 0.02091; recon_loss: 0.1422; valid_recon_loss: 1.343
# Epoch-283; D_loss_gauss: 4.58; G_loss: 0.01956; recon_loss: 0.1531; valid_recon_loss: 1.407
# Epoch-284; D_loss_gauss: 4.906; G_loss: 0.02484; recon_loss: 0.1968; valid_recon_loss: 1.145
# Epoch-285; D_loss_gauss: 4.967; G_loss: 0.016; recon_loss: 0.1101; valid_recon_loss: 1.151
# Epoch-286; D_loss_gauss: 4.993; G_loss: 0.0265; recon_loss: 0.1341; valid_recon_loss: 1.233
# Epoch-287; D_loss_gauss: 5.243; G_loss: 0.01604; recon_loss: 0.137; valid_recon_loss: 1.439
# Epoch-288; D_loss_gauss: 5.166; G_loss: 0.01509; recon_loss: 0.1017; valid_recon_loss: 1.184
# Epoch-289; D_loss_gauss: 5.423; G_loss: 0.01149; recon_loss: 0.107; valid_recon_loss: 0.8322
# Epoch-290; D_loss_gauss: 5.511; G_loss: 0.04319; recon_loss: 0.1068; valid_recon_loss: 1.002
# Epoch-291; D_loss_gauss: 5.471; G_loss: 0.01739; recon_loss: 0.1506; valid_recon_loss: 0.9178
# Epoch-292; D_loss_gauss: 5.499; G_loss: 0.01172; recon_loss: 0.1518; valid_recon_loss: 1.303
# Epoch-293; D_loss_gauss: 5.238; G_loss: 0.01852; recon_loss: 0.09859; valid_recon_loss: 1.232
# Epoch-294; D_loss_gauss: 5.351; G_loss: 0.02342; recon_loss: 0.1296; valid_recon_loss: 1.249
# Epoch-295; D_loss_gauss: 5.153; G_loss: 0.01504; recon_loss: 0.1553; valid_recon_loss: 1.205
# Epoch-296; D_loss_gauss: 5.391; G_loss: 0.02699; recon_loss: 0.203; valid_recon_loss: 1.403
# Epoch-297; D_loss_gauss: 5.114; G_loss: 0.02124; recon_loss: 0.1275; valid_recon_loss: 1.308
# Epoch-298; D_loss_gauss: 5.205; G_loss: 0.02124; recon_loss: 0.1162; valid_recon_loss: 1.063
# Epoch-299; D_loss_gauss: 5.645; G_loss: 0.01829; recon_loss: 0.2005; valid_recon_loss: 1.583
# Epoch-300; D_loss_gauss: 5.589; G_loss: 0.007708; recon_loss: 0.1647; valid_recon_loss: 1.457
# Epoch-301; D_loss_gauss: 5.655; G_loss: 0.01655; recon_loss: 0.1409; valid_recon_loss: 1.687
# Epoch-302; D_loss_gauss: 5.699; G_loss: 0.01518; recon_loss: 0.1436; valid_recon_loss: 1.272
# Epoch-303; D_loss_gauss: 5.555; G_loss: 0.0189; recon_loss: 0.2058; valid_recon_loss: 0.8923
# Epoch-304; D_loss_gauss: 5.251; G_loss: 0.02011; recon_loss: 0.185; valid_recon_loss: 1.327
# Epoch-305; D_loss_gauss: 5.028; G_loss: 0.01936; recon_loss: 0.1434; valid_recon_loss: 1.326
# Epoch-306; D_loss_gauss: 4.962; G_loss: 0.04128; recon_loss: 0.1299; valid_recon_loss: 1.189
# Epoch-307; D_loss_gauss: 4.65; G_loss: 0.05637; recon_loss: 0.1414; valid_recon_loss: 1.518
# Epoch-308; D_loss_gauss: 4.548; G_loss: 0.066; recon_loss: 0.1431; valid_recon_loss: 1.617
# Epoch-309; D_loss_gauss: 4.389; G_loss: 0.04909; recon_loss: 0.09736; valid_recon_loss: 1.52
# Epoch-310; D_loss_gauss: 4.233; G_loss: 0.03951; recon_loss: 0.122; valid_recon_loss: 1.197
# Epoch-311; D_loss_gauss: 4.335; G_loss: 0.04351; recon_loss: 0.1282; valid_recon_loss: 1.701
# Epoch-312; D_loss_gauss: 4.139; G_loss: 0.06555; recon_loss: 0.09126; valid_recon_loss: 1.45
# Epoch-313; D_loss_gauss: 4.082; G_loss: 0.05778; recon_loss: 0.1091; valid_recon_loss: 1.653
# Epoch-314; D_loss_gauss: 4.075; G_loss: 0.05434; recon_loss: 0.1081; valid_recon_loss: 1.57
# Epoch-315; D_loss_gauss: 4.121; G_loss: 0.06475; recon_loss: 0.1049; valid_recon_loss: 1.604
# Epoch-316; D_loss_gauss: 4.027; G_loss: 0.04958; recon_loss: 0.1046; valid_recon_loss: 1.896
# Epoch-317; D_loss_gauss: 4.199; G_loss: 0.05414; recon_loss: 0.1938; valid_recon_loss: 2.451
# Epoch-318; D_loss_gauss: 4.258; G_loss: 0.03932; recon_loss: 0.09048; valid_recon_loss: 1.874
# Epoch-319; D_loss_gauss: 4.229; G_loss: 0.05118; recon_loss: 0.09771; valid_recon_loss: 1.863
# Epoch-320; D_loss_gauss: 4.238; G_loss: 0.07177; recon_loss: 0.09833; valid_recon_loss: 1.592
# Epoch-321; D_loss_gauss: 4.168; G_loss: 0.04379; recon_loss: 0.08897; valid_recon_loss: 1.592
# Epoch-322; D_loss_gauss: 4.236; G_loss: 0.048; recon_loss: 0.1812; valid_recon_loss: 1.439
# Epoch-323; D_loss_gauss: 4.182; G_loss: 0.05876; recon_loss: 0.122; valid_recon_loss: 1.484
# Epoch-324; D_loss_gauss: 3.978; G_loss: 0.06366; recon_loss: 0.08888; valid_recon_loss: 1.604
# Epoch-325; D_loss_gauss: 3.986; G_loss: 0.05941; recon_loss: 0.129; valid_recon_loss: 1.625
# Epoch-326; D_loss_gauss: 3.815; G_loss: 0.05032; recon_loss: 0.1009; valid_recon_loss: 0.9621
# Epoch-327; D_loss_gauss: 4.183; G_loss: 0.04375; recon_loss: 0.207; valid_recon_loss: 1.551
# Epoch-328; D_loss_gauss: 4.158; G_loss: 0.04098; recon_loss: 0.1153; valid_recon_loss: 1.86
# Epoch-329; D_loss_gauss: 4.507; G_loss: 0.02872; recon_loss: 0.1086; valid_recon_loss: 1.258
# Epoch-330; D_loss_gauss: 4.733; G_loss: 0.03136; recon_loss: 0.2263; valid_recon_loss: 1.137
# Epoch-331; D_loss_gauss: 4.972; G_loss: 0.01329; recon_loss: 0.1066; valid_recon_loss: 0.7124
# Epoch-332; D_loss_gauss: 5.399; G_loss: 0.01231; recon_loss: 0.1493; valid_recon_loss: 1.179
# Epoch-333; D_loss_gauss: 5.555; G_loss: 0.01455; recon_loss: 0.1208; valid_recon_loss: 1.051
# Epoch-334; D_loss_gauss: 6.153; G_loss: 0.02268; recon_loss: 0.1307; valid_recon_loss: 0.7746
# Epoch-335; D_loss_gauss: 6.035; G_loss: 0.01275; recon_loss: 0.17; valid_recon_loss: 1.188
# Epoch-336; D_loss_gauss: 6.254; G_loss: 0.01231; recon_loss: 0.1983; valid_recon_loss: 0.9498
# Epoch-337; D_loss_gauss: 5.977; G_loss: 0.01197; recon_loss: 0.1147; valid_recon_loss: 0.7901
# Epoch-338; D_loss_gauss: 6.437; G_loss: 0.02424; recon_loss: 0.1808; valid_recon_loss: 1.387
# Epoch-339; D_loss_gauss: 6.631; G_loss: 0.02015; recon_loss: 0.2308; valid_recon_loss: 0.9331
# Epoch-340; D_loss_gauss: 6.303; G_loss: 0.03163; recon_loss: 0.1396; valid_recon_loss: 1.001
# Epoch-341; D_loss_gauss: 6.582; G_loss: 0.01131; recon_loss: 0.1582; valid_recon_loss: 0.8849
# Epoch-342; D_loss_gauss: 6.446; G_loss: 0.0121; recon_loss: 0.173; valid_recon_loss: 1.382
# Epoch-343; D_loss_gauss: 6.228; G_loss: 0.007338; recon_loss: 0.2582; valid_recon_loss: 1.114
# Epoch-344; D_loss_gauss: 5.874; G_loss: 0.01857; recon_loss: 0.1922; valid_recon_loss: 0.8519
# Epoch-345; D_loss_gauss: 5.632; G_loss: 0.02005; recon_loss: 0.1674; valid_recon_loss: 1.362
# Epoch-346; D_loss_gauss: 5.812; G_loss: 0.0288; recon_loss: 0.1894; valid_recon_loss: 1.505
# Epoch-347; D_loss_gauss: 5.626; G_loss: 0.04676; recon_loss: 0.2658; valid_recon_loss: 1.386
# Epoch-348; D_loss_gauss: 5.403; G_loss: 0.02389; recon_loss: 0.09834; valid_recon_loss: 1.571
# Epoch-349; D_loss_gauss: 5.69; G_loss: 0.01898; recon_loss: 0.2122; valid_recon_loss: 1.367
# Epoch-350; D_loss_gauss: 5.775; G_loss: 0.02724; recon_loss: 0.1641; valid_recon_loss: 0.9541
# Epoch-351; D_loss_gauss: 5.668; G_loss: 0.02084; recon_loss: 0.2186; valid_recon_loss: 0.7799
# Epoch-352; D_loss_gauss: 5.605; G_loss: 0.01855; recon_loss: 0.1488; valid_recon_loss: 0.6106
# Epoch-353; D_loss_gauss: 5.44; G_loss: 0.01608; recon_loss: 0.2487; valid_recon_loss: 0.7228
# Epoch-354; D_loss_gauss: 5.271; G_loss: 0.02927; recon_loss: 0.1988; valid_recon_loss: 0.9935
# Epoch-355; D_loss_gauss: 4.92; G_loss: 0.0442; recon_loss: 0.1501; valid_recon_loss: 0.9472
# Epoch-356; D_loss_gauss: 4.903; G_loss: 0.03321; recon_loss: 0.2275; valid_recon_loss: 1.125
# Epoch-357; D_loss_gauss: 4.642; G_loss: 0.04046; recon_loss: 0.1652; valid_recon_loss: 0.8989
# Epoch-358; D_loss_gauss: 4.629; G_loss: 0.04212; recon_loss: 0.1312; valid_recon_loss: 1.104
# Epoch-359; D_loss_gauss: 4.309; G_loss: 0.048; recon_loss: 0.2164; valid_recon_loss: 1.384
# Epoch-360; D_loss_gauss: 4.613; G_loss: 0.06327; recon_loss: 0.1225; valid_recon_loss: 0.8679
# Epoch-361; D_loss_gauss: 4.273; G_loss: 0.05935; recon_loss: 0.1235; valid_recon_loss: 1.093
# Epoch-362; D_loss_gauss: 4.207; G_loss: 0.04918; recon_loss: 0.0986; valid_recon_loss: 1.198
# Epoch-363; D_loss_gauss: 4.388; G_loss: 0.08835; recon_loss: 0.09888; valid_recon_loss: 0.8014
# Epoch-364; D_loss_gauss: 4.159; G_loss: 0.0537; recon_loss: 0.1419; valid_recon_loss: 1.261
# Epoch-365; D_loss_gauss: 4.087; G_loss: 0.06078; recon_loss: 0.1305; valid_recon_loss: 1.375
# Epoch-366; D_loss_gauss: 4.226; G_loss: 0.0768; recon_loss: 0.1116; valid_recon_loss: 1.073
# Epoch-367; D_loss_gauss: 4.006; G_loss: 0.04373; recon_loss: 0.09046; valid_recon_loss: 0.6164
# Epoch-368; D_loss_gauss: 4.139; G_loss: 0.06151; recon_loss: 0.08483; valid_recon_loss: 1.096
# Epoch-369; D_loss_gauss: 3.932; G_loss: 0.03863; recon_loss: 0.1006; valid_recon_loss: 1.722
# Epoch-370; D_loss_gauss: 4.227; G_loss: 0.06865; recon_loss: 0.09683; valid_recon_loss: 1.093
# Epoch-371; D_loss_gauss: 4.15; G_loss: 0.06086; recon_loss: 0.1027; valid_recon_loss: 1.851
# Epoch-372; D_loss_gauss: 4.049; G_loss: 0.05784; recon_loss: 0.09072; valid_recon_loss: 1.444
# Epoch-373; D_loss_gauss: 4.143; G_loss: 0.06098; recon_loss: 0.1064; valid_recon_loss: 1.569
# Epoch-374; D_loss_gauss: 4.056; G_loss: 0.05372; recon_loss: 0.08335; valid_recon_loss: 1.788
# Epoch-375; D_loss_gauss: 4.292; G_loss: 0.04111; recon_loss: 0.2358; valid_recon_loss: 1.759
# Epoch-376; D_loss_gauss: 4.625; G_loss: 0.04228; recon_loss: 0.1913; valid_recon_loss: 1.181
# Epoch-377; D_loss_gauss: 4.604; G_loss: 0.03399; recon_loss: 0.07308; valid_recon_loss: 2.008
# Epoch-378; D_loss_gauss: 4.478; G_loss: 0.0449; recon_loss: 0.1593; valid_recon_loss: 1.528
# Epoch-379; D_loss_gauss: 4.461; G_loss: 0.03389; recon_loss: 0.08827; valid_recon_loss: 1.673
# Epoch-380; D_loss_gauss: 4.553; G_loss: 0.05772; recon_loss: 0.1176; valid_recon_loss: 1.134
# Epoch-381; D_loss_gauss: 4.425; G_loss: 0.05597; recon_loss: 0.1044; valid_recon_loss: 1.52
# Epoch-382; D_loss_gauss: 4.36; G_loss: 0.06759; recon_loss: 0.1483; valid_recon_loss: 1.94
# Epoch-383; D_loss_gauss: 4.616; G_loss: 0.03177; recon_loss: 0.2805; valid_recon_loss: 1.321
# Epoch-384; D_loss_gauss: 4.647; G_loss: 0.03376; recon_loss: 0.1038; valid_recon_loss: 1.222
# Epoch-385; D_loss_gauss: 5.149; G_loss: 0.05743; recon_loss: 0.1177; valid_recon_loss: 1.51
# Epoch-386; D_loss_gauss: 5.331; G_loss: 0.03935; recon_loss: 0.2082; valid_recon_loss: 1.338
# Epoch-387; D_loss_gauss: 5.122; G_loss: 0.01458; recon_loss: 0.1813; valid_recon_loss: 1.879
# Epoch-388; D_loss_gauss: 5.169; G_loss: 0.01817; recon_loss: 0.1327; valid_recon_loss: 2.005
# Epoch-389; D_loss_gauss: 4.964; G_loss: 0.01622; recon_loss: 0.1181; valid_recon_loss: 2.186
# Epoch-390; D_loss_gauss: 5.046; G_loss: 0.02665; recon_loss: 0.1116; valid_recon_loss: 2.23
# Epoch-391; D_loss_gauss: 4.761; G_loss: 0.05077; recon_loss: 0.1246; valid_recon_loss: 2.416
# Epoch-392; D_loss_gauss: 4.607; G_loss: 0.03785; recon_loss: 0.09196; valid_recon_loss: 1.327
# Epoch-393; D_loss_gauss: 4.448; G_loss: 0.05278; recon_loss: 0.1014; valid_recon_loss: 1.354
# Epoch-394; D_loss_gauss: 4.522; G_loss: 0.03752; recon_loss: 0.1555; valid_recon_loss: 2.252
# Epoch-395; D_loss_gauss: 4.531; G_loss: 0.03533; recon_loss: 0.07506; valid_recon_loss: 1.439
# Epoch-396; D_loss_gauss: 4.696; G_loss: 0.05013; recon_loss: 0.09862; valid_recon_loss: 2.996
# Epoch-397; D_loss_gauss: 4.712; G_loss: 0.0304; recon_loss: 0.08454; valid_recon_loss: 1.814
# Epoch-398; D_loss_gauss: 4.829; G_loss: 0.07351; recon_loss: 0.08194; valid_recon_loss: 2.162
# Epoch-399; D_loss_gauss: 4.881; G_loss: 0.03138; recon_loss: 0.074; valid_recon_loss: 3.171
# Epoch-400; D_loss_gauss: 4.897; G_loss: 0.03956; recon_loss: 0.1221; valid_recon_loss: 1.309
# Epoch-401; D_loss_gauss: 5.066; G_loss: 0.02362; recon_loss: 0.122; valid_recon_loss: 2.273
# Epoch-402; D_loss_gauss: 5.104; G_loss: 0.02773; recon_loss: 0.2465; valid_recon_loss: 2.265
# Epoch-403; D_loss_gauss: 5.374; G_loss: 0.04835; recon_loss: 0.2686; valid_recon_loss: 2.313
# Epoch-404; D_loss_gauss: 5.297; G_loss: 0.04728; recon_loss: 0.1356; valid_recon_loss: 2.114
# Epoch-405; D_loss_gauss: 5.277; G_loss: 0.01204; recon_loss: 0.1755; valid_recon_loss: 2.16
# Epoch-406; D_loss_gauss: 5.255; G_loss: 0.01386; recon_loss: 0.2043; valid_recon_loss: 1.859
# Epoch-407; D_loss_gauss: 5.348; G_loss: 0.04411; recon_loss: 0.1394; valid_recon_loss: 1.981
# Epoch-408; D_loss_gauss: 5.534; G_loss: 0.01394; recon_loss: 0.1107; valid_recon_loss: 1.579
# Epoch-409; D_loss_gauss: 5.376; G_loss: 0.009458; recon_loss: 0.1396; valid_recon_loss: 1.364
# Epoch-410; D_loss_gauss: 5.592; G_loss: 0.04335; recon_loss: 0.08152; valid_recon_loss: 1.671
# Epoch-411; D_loss_gauss: 5.332; G_loss: 0.0389; recon_loss: 0.09649; valid_recon_loss: 1.629
# Epoch-412; D_loss_gauss: 5.482; G_loss: 0.0486; recon_loss: 0.1506; valid_recon_loss: 2.217
# Epoch-413; D_loss_gauss: 5.6; G_loss: 0.01188; recon_loss: 0.07396; valid_recon_loss: 1.876
# Epoch-414; D_loss_gauss: 5.623; G_loss: 0.02309; recon_loss: 0.1053; valid_recon_loss: 1.745
# Epoch-415; D_loss_gauss: 5.419; G_loss: 0.0262; recon_loss: 0.1022; valid_recon_loss: 1.233
# Epoch-416; D_loss_gauss: 5.207; G_loss: 0.02529; recon_loss: 0.09921; valid_recon_loss: 1.68
# Epoch-417; D_loss_gauss: 5.29; G_loss: 0.03624; recon_loss: 0.09022; valid_recon_loss: 1.498
# Epoch-418; D_loss_gauss: 5.429; G_loss: 0.02396; recon_loss: 0.1278; valid_recon_loss: 1.492
# Epoch-419; D_loss_gauss: 4.864; G_loss: 0.02249; recon_loss: 0.08268; valid_recon_loss: 1.668
# Epoch-420; D_loss_gauss: 5.286; G_loss: 0.03609; recon_loss: 0.1094; valid_recon_loss: 1.442
# Epoch-421; D_loss_gauss: 5.141; G_loss: 0.02863; recon_loss: 0.1059; valid_recon_loss: 1.676
# Epoch-422; D_loss_gauss: 4.821; G_loss: 0.02995; recon_loss: 0.08797; valid_recon_loss: 1.927
# Epoch-423; D_loss_gauss: 4.835; G_loss: 0.03209; recon_loss: 0.0698; valid_recon_loss: 1.686
# Epoch-424; D_loss_gauss: 4.952; G_loss: 0.04734; recon_loss: 0.06702; valid_recon_loss: 1.649
# Epoch-425; D_loss_gauss: 4.97; G_loss: 0.0255; recon_loss: 0.1068; valid_recon_loss: 2.029
# Epoch-426; D_loss_gauss: 5.267; G_loss: 0.02606; recon_loss: 0.08562; valid_recon_loss: 1.539
# Epoch-427; D_loss_gauss: 5.062; G_loss: 0.03469; recon_loss: 0.1362; valid_recon_loss: 1.644
# Epoch-428; D_loss_gauss: 5.291; G_loss: 0.03218; recon_loss: 0.1944; valid_recon_loss: 2.106
# Epoch-429; D_loss_gauss: 5.462; G_loss: 0.06609; recon_loss: 0.1052; valid_recon_loss: 2.049
# Epoch-430; D_loss_gauss: 5.428; G_loss: 0.03262; recon_loss: 0.2009; valid_recon_loss: 2.34
# Epoch-431; D_loss_gauss: 5.434; G_loss: 0.01297; recon_loss: 0.1484; valid_recon_loss: 2.134
# Epoch-432; D_loss_gauss: 5.167; G_loss: 0.01704; recon_loss: 0.1626; valid_recon_loss: 2.153
# Epoch-433; D_loss_gauss: 5.181; G_loss: 0.02695; recon_loss: 0.08459; valid_recon_loss: 2.511
# Epoch-434; D_loss_gauss: 5.194; G_loss: 0.03118; recon_loss: 0.1258; valid_recon_loss: 2.517
# Epoch-435; D_loss_gauss: 5.166; G_loss: 0.03564; recon_loss: 0.1724; valid_recon_loss: 2.593
# Epoch-436; D_loss_gauss: 5.205; G_loss: 0.0196; recon_loss: 0.1503; valid_recon_loss: 1.72
# Epoch-437; D_loss_gauss: 4.985; G_loss: 0.04845; recon_loss: 0.2029; valid_recon_loss: 2.031
# Epoch-438; D_loss_gauss: 4.981; G_loss: 0.0491; recon_loss: 0.1011; valid_recon_loss: 1.795
# Epoch-439; D_loss_gauss: 5.291; G_loss: 0.03876; recon_loss: 0.1201; valid_recon_loss: 1.731
# Epoch-440; D_loss_gauss: 5.189; G_loss: 0.01442; recon_loss: 0.09736; valid_recon_loss: 1.868
# Epoch-441; D_loss_gauss: 5.217; G_loss: 0.0153; recon_loss: 0.1677; valid_recon_loss: 1.474
# Epoch-442; D_loss_gauss: 5.758; G_loss: 0.01619; recon_loss: 0.1019; valid_recon_loss: 1.549
# Epoch-443; D_loss_gauss: 5.445; G_loss: 0.02093; recon_loss: 0.05878; valid_recon_loss: 1.871
# Epoch-444; D_loss_gauss: 5.587; G_loss: 0.01599; recon_loss: 0.1662; valid_recon_loss: 1.9
# Epoch-445; D_loss_gauss: 5.182; G_loss: 0.02841; recon_loss: 0.0735; valid_recon_loss: 2.333
# Epoch-446; D_loss_gauss: 5.171; G_loss: 0.01465; recon_loss: 0.2036; valid_recon_loss: 1.833
# Epoch-447; D_loss_gauss: 4.935; G_loss: 0.02995; recon_loss: 0.3403; valid_recon_loss: 2.694
# Epoch-448; D_loss_gauss: 5.268; G_loss: 0.03812; recon_loss: 0.1595; valid_recon_loss: 1.735
# Epoch-449; D_loss_gauss: 5.762; G_loss: 0.02189; recon_loss: 0.09141; valid_recon_loss: 1.475
# Epoch-450; D_loss_gauss: 6.034; G_loss: 0.01792; recon_loss: 0.0682; valid_recon_loss: 2.013
# Epoch-451; D_loss_gauss: 6.184; G_loss: 0.006182; recon_loss: 0.1641; valid_recon_loss: 1.865
# Epoch-452; D_loss_gauss: 6.253; G_loss: 0.00939; recon_loss: 0.1119; valid_recon_loss: 1.829
# Epoch-453; D_loss_gauss: 5.882; G_loss: 0.01619; recon_loss: 0.198; valid_recon_loss: 1.704
# Epoch-454; D_loss_gauss: 6.735; G_loss: 0.02453; recon_loss: 0.4546; valid_recon_loss: 2.173
# Epoch-455; D_loss_gauss: 6.917; G_loss: 0.005331; recon_loss: 0.1435; valid_recon_loss: 1.278
# Epoch-456; D_loss_gauss: 7.199; G_loss: 0.007543; recon_loss: 0.7552; valid_recon_loss: 2.234
# Epoch-457; D_loss_gauss: 7.958; G_loss: 0.009421; recon_loss: 0.2457; valid_recon_loss: 1.779
# Epoch-458; D_loss_gauss: 7.807; G_loss: 0.00715; recon_loss: 0.1966; valid_recon_loss: 1.242
# Epoch-459; D_loss_gauss: 8.422; G_loss: 0.0201; recon_loss: 0.2717; valid_recon_loss: 1.276
# Epoch-460; D_loss_gauss: 8.472; G_loss: 0.01251; recon_loss: 0.475; valid_recon_loss: 1.723
# Epoch-461; D_loss_gauss: 8.394; G_loss: 0.02009; recon_loss: 0.5455; valid_recon_loss: 1.364
# Epoch-462; D_loss_gauss: 8.962; G_loss: 0.004182; recon_loss: 0.2927; valid_recon_loss: 1.616
# Epoch-463; D_loss_gauss: 8.815; G_loss: 0.003092; recon_loss: 0.262; valid_recon_loss: 1.297
# Epoch-464; D_loss_gauss: 8.9; G_loss: 0.01019; recon_loss: 0.2346; valid_recon_loss: 1.476
# Epoch-465; D_loss_gauss: 8.846; G_loss: 0.02231; recon_loss: 0.2396; valid_recon_loss: 1.282
# Epoch-466; D_loss_gauss: 8.591; G_loss: 0.02638; recon_loss: 0.2487; valid_recon_loss: 1.324
# Epoch-467; D_loss_gauss: 8.615; G_loss: 0.003309; recon_loss: 0.2071; valid_recon_loss: 1.98
# Epoch-468; D_loss_gauss: 8.393; G_loss: 0.01433; recon_loss: 0.1245; valid_recon_loss: 1.794
# Epoch-469; D_loss_gauss: 8.283; G_loss: 0.01765; recon_loss: 0.2645; valid_recon_loss: 1.77
# Epoch-470; D_loss_gauss: 8.151; G_loss: 0.01971; recon_loss: 0.2622; valid_recon_loss: 0.733
# Epoch-471; D_loss_gauss: 8.055; G_loss: 0.002355; recon_loss: 0.2582; valid_recon_loss: 1.032
# Epoch-472; D_loss_gauss: 8.021; G_loss: 0.001094; recon_loss: 0.3447; valid_recon_loss: 2.211
# Epoch-473; D_loss_gauss: 8.305; G_loss: 0.002001; recon_loss: 0.2883; valid_recon_loss: 2.39
# Epoch-474; D_loss_gauss: 7.828; G_loss: 0.005188; recon_loss: 0.2498; valid_recon_loss: 2.263
# Epoch-475; D_loss_gauss: 7.689; G_loss: 0.02705; recon_loss: 0.1808; valid_recon_loss: 1.639
# Epoch-476; D_loss_gauss: 7.971; G_loss: 0.005807; recon_loss: 0.2096; valid_recon_loss: 2.079
# Epoch-477; D_loss_gauss: 7.802; G_loss: 0.005174; recon_loss: 0.1411; valid_recon_loss: 2.065
# Epoch-478; D_loss_gauss: 7.967; G_loss: 0.003683; recon_loss: 0.1895; valid_recon_loss: 2.089
# Epoch-479; D_loss_gauss: 8.377; G_loss: 0.01141; recon_loss: 0.2725; valid_recon_loss: 2.026
# Epoch-480; D_loss_gauss: 9.111; G_loss: 0.005125; recon_loss: 0.2024; valid_recon_loss: 1.569
# Epoch-481; D_loss_gauss: 9.044; G_loss: 0.0108; recon_loss: 0.179; valid_recon_loss: 1.235
# Epoch-482; D_loss_gauss: 9.433; G_loss: 0.00787; recon_loss: 0.1768; valid_recon_loss: 1.781
# Epoch-483; D_loss_gauss: 9.657; G_loss: 0.006726; recon_loss: 0.2462; valid_recon_loss: 1.427
# Epoch-484; D_loss_gauss: 9.936; G_loss: 0.005363; recon_loss: 0.2448; valid_recon_loss: 1.578
# Epoch-485; D_loss_gauss: 9.824; G_loss: 0.009542; recon_loss: 0.2378; valid_recon_loss: 2.054
# Epoch-486; D_loss_gauss: 10.1; G_loss: 0.0316; recon_loss: 0.1977; valid_recon_loss: 1.087
# Epoch-487; D_loss_gauss: 9.875; G_loss: 0.02156; recon_loss: 0.2002; valid_recon_loss: 1.275
# Epoch-488; D_loss_gauss: 10.0; G_loss: 0.005641; recon_loss: 0.251; valid_recon_loss: 1.498
# Epoch-489; D_loss_gauss: 10.08; G_loss: 0.003503; recon_loss: 0.1924; valid_recon_loss: 0.8944
# Epoch-490; D_loss_gauss: 10.22; G_loss: 0.003796; recon_loss: 0.2383; valid_recon_loss: 1.602
# Epoch-491; D_loss_gauss: 9.861; G_loss: 0.0205; recon_loss: 0.2012; valid_recon_loss: 1.665
# Epoch-492; D_loss_gauss: 10.15; G_loss: 0.01627; recon_loss: 0.1795; valid_recon_loss: 1.502
# Epoch-493; D_loss_gauss: 10.04; G_loss: 0.003505; recon_loss: 0.18; valid_recon_loss: 2.003
# Epoch-494; D_loss_gauss: 8.909; G_loss: 0.008904; recon_loss: 0.3597; valid_recon_loss: 1.506
# Epoch-495; D_loss_gauss: 9.881; G_loss: 0.003317; recon_loss: 0.3111; valid_recon_loss: 1.797
# Epoch-496; D_loss_gauss: 10.34; G_loss: 0.004991; recon_loss: 0.308; valid_recon_loss: 1.585
# Epoch-497; D_loss_gauss: 11.68; G_loss: 0.0212; recon_loss: 0.1583; valid_recon_loss: 0.8492
# Epoch-498; D_loss_gauss: 10.58; G_loss: 0.001874; recon_loss: 0.17; valid_recon_loss: 1.337
# Epoch-499; D_loss_gauss: 11.4; G_loss: 0.00144; recon_loss: 0.1588; valid_recon_loss: 1.75

# %%
import PIL.Image
from io import BytesIO
import IPython.display
import numpy as np
import math

def hardcodedTransform(array):
    return (1-array/255)

def transformForNetwork(array):
    return Variable(torch.FloatTensor( hardcodedTransform(array.reshape(imagesize['x']*imagesize['y']*imagesize['c'])))).cuda()

def showarray(a,do = False, fmt='png'):
    #a = np.uint8(hardcodedTransform(a)*256)
    f = BytesIO()
    if imagesize['c'] == 1:
        PIL.Image.fromarray(a.reshape(imagesize['x'],imagesize['y'])).save(f, fmt)
        IPython.display.display(IPython.display.Image(data=f.getvalue()))
    if imagesize['c'] == 3:
        plt.imshow(a)
        plt.show()

# %%
from PIL import Image
from IPython.display import Image, display

TINY = 1e-15
train_batch_size = 1

my_loader = load_data()

i = 0
max_images = 20
out = []
imgList = np.zeros((max_images,imagesize['x'],imagesize['y'],imagesize['c']))
reconimgList = np.zeros((max_images,imagesize['x'],imagesize['y'],imagesize['c']))
imgZValue = np.zeros((max_images,z_dim))
filepath = "data/train_data"
hdf5_file = tables.open_file(filepath, "r")
# To access images array:
trainset_unlabeled = hdf5_file.root.images
batches = np.split(trainset_unlabeled, len(trainset_unlabeled)/train_batch_size)
for  X in batches:
    if i>=max_images:
        break
    out = X[0]
    imgList[i] = out
    t = Q(transformForNetwork(out))
    imgZValue[i] = t.cpu().data.numpy()
    reconimg =  P(t)
    reconimgList[i] = reconimg.cpu().data.numpy().reshape(imagesize['x'],imagesize['y'],imagesize['c'])
    showarray(out)
    showarray(1-(reconimgList[i]))
    i+=1

# %%
showarray(imgList[0])

# %%
diff_matrix = np.zeros((max_images,max_images))
for i in range(0,max_images):
    for j in range(0,max_images):
        #print(diff_matrix[i,j])
        diff_matrix[i,j]=math.sqrt(sum(np.power(imgZValue[i] - imgZValue[j],2)))
        #print(imgZValue[i] - imgZValue[j])
#print(diff_matrix)
plt.scatter(imgZValue[:,0],imgZValue[:,1])
plt.show()
